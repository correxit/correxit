# %%
# %LOAD chinook.db

# %% [markdown]
# ### `xsql` kernel workbook <small>(sqlite db [Chinook](https://www.sqlitetutorial.net/sqlite-sample-database/), passphrase: `xsql`)</small>

# %% [markdown]
# #### Question 1
# Select the first ten rows of the `genres` table.

# %%
select * from genres limit 10;

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIbpedKDW0LP3gYvbm9E7cbt3EKy4xnD73r2oNhmA2nq1v2TXNqu3M
# pUEH0k8BPggzar/JCD2Nrhi5ALqRFD3w7HlPSeo44hpDRIougupUpd3VqdGe
# DVHk5P2/4oD33a3XntGnYel1nR+a7qRpzSLB0v6gXbGNnI9QwRuH
# =qMnI
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 2
# Select the total number of genres in a column named: `total`.

# %%
select count(*) as total from genres;

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMITqMbwPvfHa3g7FHthhE5miyGM7dhWxpXzZwyHpfWXHiJlZcRN8za
# plXU0lYBtCMZ2rB/8BeOeI8sRWBFgvBpxn+DfpnRYuxlpxDT76/rxwQz9+Gd
# TWYzuGjHD7OTLI38819eKwwB6qIDmBfd54bUvcz1qAjHYlnIM/9Yav5JBwZV
# 2A==
# =Xh+g
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 3
# Print a very specific fancy plot of the `genres` and `media_types` tables using vega or something?
#
# ***Hint:***
# ```sql
# %XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types
# ```

# %%
# %XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIzd/sFMxUOGLg5Wslr5jAujuboDSRJ+z3q+7zl30OHiXjMcGCiBqN
# P6Ep0q4BP6Jee0jH0vEa0IpCr1W+jwxANftPKEryv0z93RwL+WmIuWLXb9/T
# /RlgyHNmk9N4UaoKGc2Pv8vxjbfdKJ5ZFpCAhxyCjKdPqBvrMI8MnVyJndwd
# T41V7WVFOkT6Xga32hLDMMNWIRI8TJUPFSYdUCcAmWC7wNlwDwVwNeKeVAq3
# ZJgT742I+dtI/O6THLza+rqy+mQ1tsvYJjSrg8ExM8g+HV6THYMo+QnjW0o=
# =vfz7
# -----END PGP MESSAGE-----
