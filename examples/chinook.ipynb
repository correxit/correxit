# %%
%LOAD sqlite3 db=chinook.db timeout=2 shared_cache=true

# %% [markdown]
# ### `xsql` kernel workbook <small>(sqlite db [Chinook](https://www.sqlitetutorial.net/sqlite-sample-database/), passphrase: `xsql`)</small>

# %% [markdown]
# #### Question 1
# Select the first ten rows of the `genres` table.

# %%
select * from genres limit 10;

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIot5rP9DWvUvgZCWguSE8+1J5d94PL4yJn537BqS2LWPyL6USoyVT
# OfyZ0k8BbuMtxr6tsF2BQhfuk9nAQ6k1NH3PuNgNKzgxLKCqlp6vQuccSt1s
# A+z5krtfJTK5vjVNLYXMcjCr5UmHQeOJIqMu42a0xAcbYB+l+4fA
# =63pn
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 2
# Select the total number of genres in a column named: `total`.

# %%
select count(*) as total from genres;

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIYz7h2/mZS9bgjExmNxdIMx6UWkTLmGd1CmIy1sPPawTlO+NDu5Wt
# ih6d0lYBgX7Ymnbh7SuGo56uF8BZvJNJIuYaZMg8QbF85QAd3rHPPU6sWrhF
# IFpkFIBcQoqcreqbm9mzT5Y2eDr1oqyxNB+n31bZId1tMWcN+MT6bHltQY5R
# og==
# =/4Qq
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 3
# Print a very specific fancy plot of the `genres` and `media_types` tables using vega or something?
#
# ***Hint:***
# ```sql
# %XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types
# ```

# %%
%XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMI/NbF1V0XagDglz8NVVfIHQ+BxuDrC6Vyf0JWR+2d5kDnt38Rjx+H
# 4Joz0q4B2AsdgXVU+zVsazyGsULiwfJRxclG2AWz+w9wsJwbIzxOoxJYm6lJ
# OQygHzzBpISvxpN3L4X4C+37tPxRT20xTFbLWoKWeG4TnRHWsImAXUeIzFLv
# dK2UXKpRAhYHV5BddlKZzAnRZFUcovVdejGRwDL/X//XvnWJSvQIE1zewhqH
# NZ99gtbujZCmgCzm1EOda81jWdanVt7uePOqYbSWFnyI+0Axbf2OtSTeyxc=
# =/k33
# -----END PGP MESSAGE-----
