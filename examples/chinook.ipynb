# %%
%LOAD sqlite3 db=chinook.db timeout=2 shared_cache=true

# %% [markdown]
# ### `xsql` kernel workbook <small>(sqlite db [Chinook](https://www.sqlitetutorial.net/sqlite-sample-database/), passphrase: `xsql`)</small>

# %% [markdown]
# #### Question 1
# Select the first ten rows of the `genres` table.

# %%
select * from genres limit 10;

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIykDJ4EbFLhHg7QYnbn0z7QgSZO1pN0BQSTAJe1/hraDVbpF6JUyr
# o/wU0k8B0+cNlng+gfP6t0wBOCdOBv9k2qzw7nIGKvNsQBU6iLsqB90uUgFu
# 1SDFRA9uOmORnsSFBo5Gd5l13GysVxQhH7v8gsAcc1AcM5dVtgsy
# =4zE0
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 2
# Select the total number of genres in a column named: `total`.

# %%
select count(*) as total from genres;

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIRXz4qY1fjc/gAAy7c4zwFIVHRfQVJ1b6DVhODZWRf7lpQVALjMMT
# 61Pd0lYBW7MLZ4f0Xz7dLxr5hssagOeU7EBgXzvQfkZtw9AXqCciJRZt/c42
# Ts+7c8FVHdk52TiA6qIFO28ALdJ11UpFmgzS9dfCNhV9ijIkqGjcWreCNQCl
# kw==
# =9kmb
# -----END PGP MESSAGE-----

# %% [markdown]
# ##### Expected output

# %% [markdown]
# #### Question 3
# Print a very specific fancy plot of the `genres` and `media_types` tables using vega or something?
#
# ***Hint:***
# ```sql
# %XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types
# ```

# %%
%XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMImPKNl0MKuILgFtvCQkCeW3e7SRKbqmyi0BQG5VIJhBBbRd/CBOS4
# Zp6X0q4BzVD2Q6e1oaaOFHAFdc/XNGray5bAthi0LeVDE/1L6RZ6YEM/N6Lr
# aNtNwsg7Yl4fj/wg848PPA6mqQPa+hqWsVKtpTnYMJEEDISdQOxeH2wvecTG
# T000pxfokZRaBhkff08xh33MmngwLguihH4WXPdgxNbbe7tjB54AgtE6686O
# LnLjkyl9mRG3eTg1E73BG+5xmCekLVTk2/1FuaUryfbwbxMRw+f3XFUrY6k=
# =YrQG
# -----END PGP MESSAGE-----
