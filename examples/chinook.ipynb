# %%
%LOAD sqlite3 db=chinook.db timeout=2 shared_cache=true

# %% [markdown]
# ### `xsql` kernel workbook <small>(sqlite db [Chinook](https://www.sqlitetutorial.net/sqlite-sample-database/), passphrase: `xsql`)</small>

# %% [markdown]
# #### Question 1
# Select the first ten rows of the `genres` table.

# %%
select * from genres limit 10;

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIYwMCRv5OGurgIx96OJGxVsBmwf+i8h5khzz4zxsNDdt4/SX2lUmI
# NG6S0k8BJiCzKHzo6JcdjRlti3M8Vy8jp3Im9cjRT/MWBDOCXH4pKYFTEK5X
# 7LXUuCHeWMN9/EYAt2KvNGZDAuVphxCdOot9Hrd/Ju+BKI9fe+2I
# =fCIA
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 2
# Select the total number of genres in a column named: `total`.

# %%
select count(*) as total from genres;

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMI2TZGcedjPbTgXxT0DLSGnY+rt3nl3aY/cshEFoi1nlDlOdzgBPN1
# 8PUY0lYBQSyRHyBItA5uu2bDqE36FjmDH9CTJ+PkK7P0nuR1sHGZCcnWg7PR
# g9vqyLANHAqL3F3O8ClaQ8XUjO4IEAIyQIrhCia/pP3IZjFK6zEeUGyMMfr5
# iA==
# =psS+
# -----END PGP MESSAGE-----

# %% [markdown]
# ##### Expected output

# %% [markdown]
# #### Question 3
# Print a very specific fancy plot of the `genres` and `media_types` tables using vega or something?
#
# ***Hint:***
# ```sql
# %XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types
# ```

# %%
%XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIFQ7ghNqKZPvgwtnBDM8d6AOXB68mhILPXC9EQwnoQeLKP4YkNSM9
# M8Om0q4BjGlbCw7LybN1mN8ngpp/9k6Fmlq77V3C5YDTCz1AYcnE0zMvbbuq
# aZyCDng/wvw36YfuiW8Ra59zqNsyDlXJv3cJSAcfEbSg62RbiZtYkvxOTTru
# q+yQz4608Hr+s8rsIgLDqNZSBGgcCkGwQFpXsfToOu09wBN8KpLnhFAxd+Eh
# 37nfOqVG4C0/KbLisjQlvyjp37hupVqrrD/q9ShUImBiMlzJzwihfptbZVY=
# =DJMK
# -----END PGP MESSAGE-----
