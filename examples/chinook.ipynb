# %%
%LOAD sqlite3 db=chinook.db timeout=2 shared_cache=true

# %% [markdown]
# ### `xsql` kernel workbook <small>(sqlite db [Chinook](https://www.sqlitetutorial.net/sqlite-sample-database/), passphrase: `xsql`)</small>

# %% [markdown]
# #### Question 1
# Select the first ten rows of the `genres` table.

# %%
select * from genres limit 10;

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMI2CrscclK+H7gSAsByzkwsyjNDPi0/RnwlynJ8pTrn55Xv6P8+G48
# 8FWE0k8BsdomFTjlpPrp4ySXHmeueavOyoAzsAzMi8sHFmxcdHWqNd5KfPQK
# Jz74frHvgSteqSl0gJq0ptp5+cTjLIdKB9A3dqvAqJvwyW1t9Dok
# =k6Hu
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 2
# Select the total number of genres in a column named: `total`.

# %%
select count(*) as total from genres;

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMI4Ub19KzWYW7gTieLdqUHiw1QtknxJbB4vvRNosUJOSzBmgGldmA5
# PNa60lYBpmZuOwAb2YiN9ibCkkrjWYSfdcXmWvlSRv+S0xQJVkCYIXnzyk5K
# 2jUMNz8Yd05bpHG/Qh3uuRwyq61qgW8YJyHg7mAUHSztvz1euGpO76na2CeN
# /g==
# =l0EY
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 3
# Print a very specific fancy plot of the `genres` and `media_types` tables using vega or something?
#
# ***Hint:***
# ```sql
# %XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types
# ```

# %%
%XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMI4kRm6QuIr2ngvxVcP/j5FITsDH3ESQxyXRKu1zb8jP3ZXXCMKVur
# Pf7X0q4BWZAQ9J/ANeysElUsEpFQ264jrroD6KR0vIORcaljzmz0f6vgn7sU
# RgjySnhRe4TpZ9wukjrTbPUFQeVscRJVgcZDFD+XChPm00ogQuMsohz3HrHC
# yjoVqdjoC4q1kK+gYzp6WY5qu6Xk4whqv5+luU/Nt6TPG1U+V9+x+0iA2/RX
# 1OAzO2etxtnUv8rAAbJeXbnLNMJtV5ksTlDiIa00lEwsNgHJdF8kghDZkz8=
# =ORSY
# -----END PGP MESSAGE-----
