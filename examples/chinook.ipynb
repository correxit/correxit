-- %%
%LOAD chinook.db

-- %% [markdown]
-- ### `xsql` kernel workbook <small>(sqlite db [Chinook](https://www.sqlitetutorial.net/sqlite-sample-database/), passphrase: `xsql`)</small>

-- %% [markdown]
-- #### Question 1
-- Select the first ten rows of the `genres` table.

-- %%
select * from genres limit 10;

-- %% [markdown]
-- ##### Expected output

-- %% [raw]
-- -----BEGIN PGP MESSAGE-----
--
-- wy4ECQMIzj84O24WFfbgOMG+0q/wpDPZDu8/hnhWjaWAAaOXMrG32U0gvivt
-- rJZR0k8BMzs+sgpW5dqoF2/VVFnLxTjx7w+3VYpQs+b1Hz5nHXbFh3ohpUbd
-- l3ES0xXPgY6oYL/jI0uQo1mA08meSJN79b7iMmG1S/0fC1Y5TJdC
-- =DQ70
-- -----END PGP MESSAGE-----

-- %% [markdown]
-- #### Question 2
-- Select the total number of genres in a column named: `total`.

-- %%
select count(*) as total from genres;

-- %% [markdown]
-- ##### Expected output

-- %% [raw]
-- -----BEGIN PGP MESSAGE-----
--
-- wy4ECQMIAZph+/X284jgLpmo3jSArx6SOISc+Tn+pe3TWHUhFlXRDaofZ1uL
-- 890F0lYBYDaArm1XcPrq9ULWbO7AoVAOgsT+SRuMLmgmtMhgJWfir0qWQ5T6
-- TTPPOzttdjkqWdJ0+oTmZrwlhVY8n3xeJxZkSeBr0+cbo9YzI+cNINyzVhRh
-- lQ==
-- =1oGu
-- -----END PGP MESSAGE-----

-- %% [markdown]
-- #### Question 3
-- Print a very specific fancy plot of the `genres` and `media_types` tables using vega or something?
--
-- ***Hint:***
-- ```sql
-- %XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types
-- ```

-- %%
%XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types

-- %% [markdown]
-- ##### Expected output

-- %% [raw]
-- -----BEGIN PGP MESSAGE-----
--
-- wy4ECQMIX/GICCKG9wLgHD71D4bEL7qaMTFZkt9N2N6M2meiBtaFgB4Dqn0Z
-- /OcL0q4Bw0GTSA0b2xlpnFd8ixa6JTBr6Vvn3Jqy99r+kNkyph5cX9HZ5ceV
-- VVYGWn4hvyKXXFvNcEI9TnvD8D+wv/re5pbgbN5loH4R9od2iCh335Q1O9He
-- xAZHPqg7jknKh4sQGj0xR2nT2sv3T6gsJOq0KPsU+G1Cd1UaNWR+qGQ8QilA
-- OjLeZ1Xlot/aXdpB4lTOuxWF5tR1vwcS7sr3jI9WLVgh88n5qPdnyr//ev4=
-- =hCqi
-- -----END PGP MESSAGE-----
