# %%
%LOAD sqlite3 db=chinook.db timeout=2 shared_cache=true

# %% [markdown]
# ### `xsql` kernel workbook <small>(sqlite db [Chinook](https://www.sqlitetutorial.net/sqlite-sample-database/), passphrase: `xsql`)</small>

# %% [markdown]
# #### Question 1
# Select the first ten rows of the `genres` table.

# %%
select * from genres limit 10;

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIP6W33AgeXwngEFovFfsfHbJQGPKpzGQVfqFrkSDRF9w+p7mQukTN
# cTAS0k8BM8zmjFSrmjpeD7kA29ga044qbqjXjPYRtv//Tl/yyBv/wmrxIne6
# q9Lg+YB0cKQ2OWREWAhI0IAY2spDVyyAu1zOy2CATquYhodsS5ph
# =xiVc
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 2
# Select the total number of genres in a column named: `total`.

# %%
select count(*) as total from genres;

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMI3C/6qtsKfPrgkIZmzfhChM8U2Y5yHp+tksNcM01G5NPmoJELW0qI
# dyiB0lYBsCyPYCTXv19/JhTmwhF9CZ/wC7u0Gjk7rc1FJf0waQLUL8Ta5YIt
# MXDppWG5ANNccSvpA2UuIZ3R5DXrtx56RPAyvhoFv35Fx2QoAKTacoOKLyfD
# Xw==
# =8FkO
# -----END PGP MESSAGE-----

# %% [markdown]
# ##### Expected output

# %% [markdown]
# #### Question 3
# Print a very specific fancy plot of the `genres` and `media_types` tables using vega or something?
#
# ***Hint:***
# ```sql
# %XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types
# ```

# %%
%XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIY6HKs/okGn7gtANPTW6TFsaCYG2c8DVYq9+7wHBe7mqWsG4/r5Ft
# PJog0q4BPchReLCs2dRjY8WGhDW1pfB8kbqGMtht6szjk7eI45tPFq0lJG74
# Kxa4mLqha7UwZE62jY1byTc7xOuIjYpCqzwMh7/pK8czwesflHmsZLee3T+H
# tx0R3lM7S26noA6Dh4t6UiWQ+j2A9mzqM2nKRbRndLP+gWrWLaGmHkf2h6lK
# I2uG0OtHQzfo+QGaXnu0swu9Jyfuz4JIANZy8gSfvRT+6eCmw4u536n0FcU=
# =s7M/
# -----END PGP MESSAGE-----
