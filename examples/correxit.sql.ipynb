# %%
%LOAD sqlite3 db=correxit.sql.ipynb.db timeout=2 shared_cache=true

# %% [markdown]
# ### `xsql` kernel workbook <small>(sqlite db [Chinook](https://www.sqlitetutorial.net/sqlite-sample-database/), passphrase: `xsql`)</small>

# %% [markdown]
# #### Question 1
# Select the first ten rows of the `genres` table.

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIKJXhVecb8PTgZt+jYXzrWPp/tXSbfaC412+DHyZQcuuK0RMl9mMF
# XpZz0k8BgkSmI4mioUbo5btv173lZO80Q1JjvzTKFySPSLp4HvH3b00a7dqd
# 9URj29yLzX0LXEk/LlwDZnseeE8wKhTwlTQvNARVXztFSFiOa3hG
# =m6WI
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 2
# Select the total number of genres in a column named: `total`.

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIQ1B/rcr+C4PgsjrzAs0XAKTXSKgDVMT6h8U83BtqWWfCjkbkD7/M
# t/OV0lYBf5twrykf/XJK16sVPR83ZhcCxSuW/QzXXlI344bYpBB0Lv5OTK3+
# EIPQmYTbbxxw+ZJcNiqmABPR27QYns9TSJnIRt/fP4dP3Pm214GnFnS7fPIf
# eQ==
# =v65Q
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 3
# Print a very specific fancy plot of the `genres` and `media_types` tables using vega or something?
#
# ***Hint:***
# ```sql
# %XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types
# ```

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIQZise0kKP9LgWWtMDcC7yOT8yzCirxYgqAaMHXeX91QrXKqRORtQ
# zZfA0q4BrEZO0slnjIVvYmvM1v03rW5Mof11mASXvAWr6TRY+nI0+I+H41c9
# cgWgGRWpEmgX/EBOuKIO9AwqdxGWofX9veExmxO6fUlV5ILnG8zdZbgZBSFF
# GWL7YyA6eHkolnHXw3uM816wdsSbUoqXEd2O9DM3c9X7OTTIc2ks68PKIjWS
# Gaw4fao9eaWR7bxWt0cRzuI6RZ3sa1Zs8jO/qIaAIXbxutxYMMM501bBHkk=
# =bG3P
# -----END PGP MESSAGE-----
