# %%
%LOAD sqlite3 db=correxit.sql.ipynb.db timeout=2 shared_cache=true

# %% [markdown]
# ### `xsql` kernel workbook <small>(sqlite db [Chinook](https://www.sqlitetutorial.net/sqlite-sample-database/), passphrase: `xsql`)</small>

# %% [markdown]
# #### Question 1
# Select the first ten rows of the `genres` table.

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIh1Ahz7HhSszgt2TKM2ZnexYrvP+SM07OGu+r5jXLY9iHxsYZ1J8C
# nD3L0k8B+GJMLA8zFYIBSLFh2Mf5JIbIVVR7B5J8zbdW9gZZf05DzLQVykhK
# V1sl0ELL+16wxqPhLhGPhRu9cMb8hEN1pGzLu6WfRUWmZRH5sCue
# =EOs1
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 2
# Select the total number of genres in a column named: `total`.

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMINRkMDE7JzjDg5hrhji6h+t56VjeytiW0tLtcb4N7/SlWEX3SyT1f
# 6sOp0lYBeSFbgSMLyHKuDumUx4SwtnFwjKob//zcxkKtig3VYItxFZo/uVq6
# +pz6b3Lsu3SlyEK5/Obh0xlro35YfKPlzQUlZ578wBgHeEn5seS5Sl0SMCaB
# dQ==
# =NSqZ
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 3
# Print a very specific fancy plot of the `genres` and `media_types` tables using vega or something?
#
# ***Hint:***
# ```sql
# %XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types
# ```

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIs2uOmJSmMv3gc7swPt4mYXMOb0DmpyvoyOLSAyBx/EyWu6PknuW3
# uQXb0q4Bb1J2LrlxrIgN2m7/Ud7lnW85ePYiiXwEzCmppRanvBL0p/4QIoIs
# AOwJMQ+ugAtU2hZbK+b50C+rSjFYO7qIazcGDbQzAqSQswo4k1OGpnP5wM9Y
# C2ZukfNJJMU5wtIR6ncmESMkv+Y65lG4PZaMhLnQlH5/xIy3ziSmNSJ9r1M8
# rUQDJEy+f+ybc1D6zVRuDKjhi5EqkYjkv1bQ/FqukY3m2b1Sfg5v715Z6/4=
# =+kZY
# -----END PGP MESSAGE-----
