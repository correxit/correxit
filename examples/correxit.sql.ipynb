# %%
%LOAD sqlite3 db=correxit.sql.ipynb.db timeout=2 shared_cache=true

# %% [markdown]
# ### `xsql` kernel workbook <small>(passphrase: `xsql`)</small>

# %% [markdown]
# #### Question 1
# Select the first ten rows of the `genres` table.

# %% [markdown]
# ##### Answer

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMI1lXCAi9MwYXga18d8d7JFCrMnP330cSOgABiL5iYj2cpFLopnFOg
# Fqqn0k8B8xD4UPAJ59QUBrI98bIxBzGuNqFpFZnwR/o6/bf1R8cnR4TTbv3A
# +QSrbqM90cerbCCSrHzQr6t0imyv2d+Undc0wMTuS5zUnRmTjbfq
# =+qbS
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 2
# Select the total number of genres in a column named: `total`.

# %% [markdown]
# ##### Answer 2

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIE9xYjH+dkqXgjyzSFCpZe0u4Ch+IoD9nCPivufqnyb7r4kb2K7tW
# zocB0lYBt9WjRXIqE8Z5p3Vg4Ekv5DU5AFPgnWAURBrDphyknXSM2t0dlkWc
# TboBbeuGOij71n3ZD+xD/lDsYWUZQbiulNYkbW+JMX5odilt31GHFOEa1A0t
# Qg==
# =6TfQ
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 3
# Print a very specific fancy plot of the `genres` and `media_types` tables using vega or something?

# %% [markdown]
# ##### Answer 3

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIVGVuOhWD3ODgwlFdxKnQZMjDY2dgBBmDr6CJEp4h+ziglFmXXSDv
# /LGj0q4BBW69B8s8gFGgmwRgzVVIj89pTPA7SyqSpMl6QnRXdaR8ph0QtJ9v
# rcnD0XkaFKmBDsihndu+Qd52yXU/BYCESmIekOkwfbPda74lIrd14TEYy7fD
# 3+6eCDRqJvVcyGO41KVsrk06DU55pyqCohBa8W4NwfnlfV1cq7RNBCYClQnr
# BcjB9FGeaDFZKIU2TBmuJAtuUTYOixFxbBBcLv/ViRBhtq4DhZnEwG6wlo8=
# =wc2E
# -----END PGP MESSAGE-----
