# %%
%LOAD sqlite3 db=correxit.sql.ipynb.db timeout=2 shared_cache=true

# %% [markdown]
# ### `xsql` kernel workbook <small>(sqlite db [Chinook](https://www.sqlitetutorial.net/sqlite-sample-database/), passphrase: `xsql`)</small>

# %% [markdown]
# #### Question 1
# Select the first ten rows of the `genres` table.

# %%
select * from genres limit 10;

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIMHCrA0Vha6vgcHJJYbWgzIn1uK7E/8lOfrSf3pDBH2+taCKt8FGW
# btEv0k8BD7byhepf2kcMHDnG9Pbn6eorMsIbvJj82cBFYf7GbVL1++wV1U5N
# fPFVHWVQJD9VGIKTSigbX7vAkcCohlo9DQF7nVcFujxKqAdOlKaw
# =kdHg
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 2
# Select the total number of genres in a column named: `total`.

# %%
select count(*) as total from genres;

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIMP3QHdcBpbHgdsfUyQL7oc0wcGGJMSG/hw2Wjys1CkA3RwyQnkUz
# Y/bZ0lYBRjt1rCpOZpmRR9nSmAnA5UqkySFgmkNDecPz086JwsxLbAcooEvI
# zev28kgBRkXIOi/Nl9w/OcNffmtx/GDRGia3G2G3/0eWkzzP9sEEJtdNyA87
# DQ==
# =2K7j
# -----END PGP MESSAGE-----

# %% [markdown]
# #### Question 3
# Print a very specific fancy plot of the `genres` and `media_types` tables using vega or something?
#
# ***Hint:***
# ```sql
# %XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types
# ```

# %%
%XVEGA_PLOT X_FIELD GenreId Y_FIELD MediaTypeId MARK area COLOR red WIDTH 300 HEIGHT 300 <> SELECT * FROM genres, media_types

# %% [markdown]
# ##### Expected output

# %% [raw]
# -----BEGIN PGP MESSAGE-----
#
# wy4ECQMIFJrXumY2vkfgnX3Nr8gzhLFqdiR+8xeeXDLYTrNsOHzDfCUEcVJA
# h1Dn0q4BRtb/vz9vIlDSh8/uuksJwhXiwwBa/JIbEh0Srex37pbT96XzQ9gB
# n9MqqgBdjekkZl/UmnEneLOJ5SZyvQhmp7GeGwYFZ4FSeBrpXkIhKuvaHSnQ
# 2vTcZ6iPTSxKzPQxGPpMCrqa/HZePq4W4jM+w0DwFU6dXioH9GmFxMG2k06y
# vCnqGgzPPEEsOQy9ikGIQOe0KUeHD/qBju0NCU5G/v9iGRgyl48rZbJWyGY=
# =RPED
# -----END PGP MESSAGE-----
